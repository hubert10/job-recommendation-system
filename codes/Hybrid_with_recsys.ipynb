# %%
import sys
import recsys.algorithm
import recsys.algorithm.factorize as SVD
from recsys.algorithm.factorize import SVD
from recsys.datamodel.data import Data
from recsys.evaluation.prediction import RMSE, MAE
import pandas as pd
recsys.algorithm.VERBOSE = True

# %%
#data = Data()
data = pd.read_csv('/home/nadine/Desktop/Hubert/Memoir/data/data/data.csv')
#data.load('/home/nadine/Desktop/Hubert/Memoir/data/udata', 'rb')

# %%
from sklearn.cross_validation import train_test_split
train_data, test_data = train_test_split(data,test_size=0.25, random_state=0)

# %%
data
# Out:
#         UserId  JobId  Rating
# 0         1513     30       2
# 1          531    134       5
# 2          170    140       5
# 3          913     22       3
# 4         2007     86       3
# 5          702     91       3
# 6         1704     16       5
# 7         1575     84       2
# 8          506     44       4
# 9         1375     76       2
# 10         275    134       4
# 11          92     83       4
# 12        1987    113       4
# 13         753    104       2
# 14        2399     53       4
# 15         859     24       2
# 16        2154     38       5
# 17        1113     80       2
# 18         590     39       4
# 19        1066      8       5
# 20        1287     94       3
# 21        2227    140       4
# 22        1140     54       4
# 23         354     11       4
# 24        1118      9       3
# 25        2023      6       4
# 26         195     27       1
# 27          96    114       5
# 28        1657     57       1
# 29        1171    142       4
# ...
