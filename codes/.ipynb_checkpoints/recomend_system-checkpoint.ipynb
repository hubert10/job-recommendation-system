# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib
import pandas
import numpy
print (matplotlib.__version__)
print (pandas.__version__)
print (numpy.__version__)
# Out:
# 1.3.1
# 0.13.1
# 1.11.2

# %%
#Reading users file:
users_data = pd.read_csv('/home/nadine/Desktop/Memoir/data/user.csv')

# %%
users_data
# Out:
#     userId          joined-date  active    birthday  gender
# 0        1  2013-12-11 16:47:33       1  1980-03-28    Male
# 1        2  2014-01-03 13:18:17       1  1987-11-03    Male
# 2        3  2014-01-17 20:10:39       1  1980-03-28    Male
# 3        4  2014-01-21 21:34:22       1  1982-10-29  Female
# 4        5  2014-02-12 20:22:48       1  0000-00-00    male
# 5        6  2014-02-20 15:55:16       1  1985-06-04  Female
# 6        7  2014-02-20 16:01:52       0  1983-10-27  Female
# 7        8  2014-03-01 20:37:41       1  1980-06-30    Male
# 8        9  2014-05-05 00:51:47       1  1988-01-02    Male
# 9       10  2014-05-09 22:28:20       1  0000-00-00    Male
# 10      11  2014-05-09 22:29:24       1  1963-09-18    Male
# 11      12  2014-05-13 16:10:00       1  1982-06-06    Male
# 12      13  2014-05-13 16:49:14       1  0000-00-00    Male
# 13      14  2014-05-14 21:47:48       1  1982-05-10    Male
# 14      15  2014-05-22 14:20:48       1  1978-04-03    Male
# 15      16  2014-05-23 18:05:54       0  0000-00-00    Male
# 16      17  2014-05-29 22:05:58       1  1992-09-10    Male
# 17      18  2014-06-05 18:04:07       1  0000-00-00    Male
# 18      19  2014-06-06 16:52:59       0  1985-09-01    Male
# 19      20  2014-06-11 12:57:51       1  0000-00-00  Female
# 20      21  2014-06-30 16:08:10       1  1987-11-03    Male
# 21      22  2014-07-01 22:01:35       1  1979-01-05    Male
# 22      23  2014-07-14 16:10:01       1  1974-10-09    Male
# 23      24  2014-07-28 15:19:35       1  1987-12-14  Female
# 24      25  2014-08-06 12:00:46       1  1995-07-06  Female
# 25      26  2014-09-01 13:11:57       0  1979-10-22  Female
# 26      27  2014-09-01 16:51:12       0  1989-10-07  Female
# 27      28  2014-09-01 17:26:06       1  1983-04-03  Female
# 28      29  2014-09-01 17:30:18       0  1983-04-03  Female
# 29      30  2014-09-01 18:22:22       0  1992-02-09  Female
# 30      31  2014-09-03 17:41:01       0  1966-01-01    Male
# 31      32  2014-09-04 12:50:15       0  1984-08-28  Female
# 32      33  2014-09-05 01:43:41       0  1993-10-03  Female
# 33      34  2014-09-05 09:55:28       1  1981-05-13    Male
# 34      35  2014-09-05 15:32:14       0  1982-05-04    Male
# 35      36  2014-09-06 12:36:55       0  2012-06-04    Male
# 36      37  2014-09-07 14:16:48       0  1991-01-20    Male
# 37      38  2014-09-07 22:15:35       0  1989-12-02  Female
# 38      39  2014-09-07 22:17:39       0  1989-12-02  Female
# 39      40  2014-09-08 16:13:49       0  1979-02-21    Male
# 40      41  2014-09-11 14:09:27       1  1977-01-28  Female
# 41      42  2014-09-11 18:15:36       0  1988-01-01  Female
# 42      43  2014-09-20 15:04:59       1  1982-09-23    Male
# 43      44  2014-09-20 16:05:50       1  1987-09-23    Male
# 44      45  2014-09-21 03:52:26       0  0000-00-00    Male
# 45      46  2014-09-21 21:05:02       0  0000-00-00    Male
# 46      47  2014-09-22 18:22:42       0  0000-00-00    Male
# 47      48  2014-10-12 00:19:23       1  1991-11-20  Female
# 48      49  2014-10-12 00:41:10       1  0000-00-00    Male
# 49      50  2014-10-17 13:02:56       1  0000-00-00    Male
# 50      51  2014-10-22 11:16:55       1  1986-06-11    Male
# 51      52  2014-10-31 11:28:08       0  1982-11-21  Female
# 52      53  2014-10-31 16:22:22       1  1988-08-27    Male
# 53      54  2014-10-31 17:00:23       1  1990-09-14  Female
# 54      55  2014-11-05 22:47:40       1  1982-11-30    Male
# 55      56  2014-11-07 13:45:58       1  0000-00-00    Male
# 56      57  2014-11-07 15:39:23       1  1990-11-30    Male
# 57      58  2014-11-09 16:22:58       1  0000-00-00    Male
# 58      59  2014-11-10 00:42:34       1  0000-00-00    Male
# 59      60  2014-11-10 08:31:58       1  1981-03-03  Female
#        ...                  ...     ...         ...     ...
#
# [1200 rows x 5 columns]

# %%
#Reading jobs file:
jobs_data = pd.read_csv('/home/nadine/Desktop/Memoir/data/jobs.csv')
jobs_data
# Out:
#     jobId                                               name  \
# 0       8                   Stagiaire en analyse des donneés
# 1       9                         Stagiaire en Sécurité info
# 2      10              Un(e) directeur(trice) des formations
# 3      12          Un(e) responsable marketing et commercial
# 4      13                    Un(e) assistant(e) de direction
# 5      15                               Vacancy Announcement
# 6      16                                         Commercial
# 7      17                   Commercial / business developper
# 8      20                  Hellofood.sn recrute un comptable
# 9      21     Africa Internet Group recruit a Cash COLLECTOR
# 10     22                             Un assistant comptable
# 11     24            Développeurs back-end & front-end (H/F)
# 12     25  La LONASE recrute un(e) Directeur(rice) des Sy...
# 13     26                   Chargé(e) de communication (H/F)
# 14     28  Assistante administrative, financière et organ...
# 15     29                      HR Business Partner - Senegal
# 16     30                                      CFO - Senegal
# 17     32  Un(e) Assistant(e) de Direction Bilingue (Fran...
# 18     33  Un (01) Senior Manager Tax (Bilingue Français ...
# 19     34  Un Manager Responsable de Département Expertis...
# 20     35                        Consultant contrôle qualité
# 21     36  Responsable du Département Expertise Comptable...
# 22     37                                  Chef de Projet SI
# 23     38                              Ingénieur Réseau Data
# 24     39                                   Ingénieur Etudes
# 25     40                                    Ingénieur Radio
# 26     41         Administrateur Système et Base de données
# 27     42              Ingénieur de Production  Informatique
# 28     43                           Administrateur Stockage
# 29     45                                           Auditeur
# 30     46                                           Auditeur
# 31     47                                         Fiscaliste
# 32     48                                         Fiscaliste
# 33     49                                          Comptable
# 34     50                                          Comptable
# 35     51            30 Ingénieurs de développement logiciel
# 36     53               10 Consultants MICROSOFT Application
# 37     54                  5 Consultants ORACLE Applications
# 38     55                     5 Consultants SAP Applications
# 39     56                              Deux (2) Chefs de pub
# 40     57             INGENIEUR ETUDES ET DEVELOPPEMENT WEB
# 41     59           Chef Comptable bilingue Français/Anglais
# 42     60                            Technico-commercial H/F
# 43     61                                          Comptable
# 44     62  Assistance à Maitrise d’Ouvrage Web & Mobile d...
# 45     63                Chef de service transferts d'argent
# 46     64             Chef de service financier et monetique
# 47     65                          Chef de produit monétique
# 48     66                                   Analyste Crédits
# 49     67                          Chef de service juridique
# 50     68                          Technicien d'exploitation
# 51     69                                          Pompistes
# 52     70                                 Technicien de Baie
# 53     71                                            Laveurs
# 54     72                              Caissier(re) boutique
# 55     73                     Administrateur Base de Données
# 56     74                                Technicien Helpdesk
# 57     75                                      Chef d'Agence
# 58     76                                       Designer Web
# 59     77                                         Archiviste
#       ...                                                ...
#
#     contract in months  Required_experience in years  \
# 0                    6                             5
# 1                    6                             4
# 2                    6                             5
# 3                    8                             3
# 4                    6                             3
# 5                    6                             5
# 6                    6                             5
# 7                    8                             5
# 8                    6                             5
# 9                    6                             2
# 10                   6                             2
# 11                   9                             1
# 12                   6                            10
# 13                   9                             1
# 14                   8                             3
# 15                   6                             5
# 16                   6                             5
# 17                   6                             3
# 18                   6                             3
# 19                   6                             5
# 20                   6                             1
# 21                   6                             5
# 22                   6                             2
# 23                   6                             3
# 24                   6                             3
# 25                   6                             3
# 26                   6                             3
# 27                   6                             3
# 28                   6                             3
# 29                   6                             2
# 30                   6                             2
# 31                   6                             2
# 32                   6                             2
# 33                   6                             2
# 34                   6                             2
# 35                   6                             1
# 36                   6                             3
# 37                   6                             3
# 38                   6                             3
# 39                   6                             3
# 40                   8                             1
# 41                   6                             5
# 42                   6                             5
# 43                   6                             2
# 44                   9                             1
# 45                   6                             5
# 46                   6                             5
# 47                   6                             4
# 48                   6                             3
# 49                   6                             3
# 50                   6                             1
# 51                   8                             1
# 52                   6                             1
# 53                   6                             1
# 54                   6                             1
# 55                   6                             3
# 56                   6                             1
# 57                   6                             4
# 58                   8                             2
# 59                   8                             2
#                    ...                           ...
#
#                                        Required_level   Posted_at  Likes  \
# 0                                                bac3  2014-04-19     17
# 1                                                bac4  2014-04-18     18
# 2                                                bac5  2014-04-17     19
# 3                                                bac2  2014-04-18     50
# 4                                                bac3  2014-04-18     74
# 5                                                bac5  2014-07-21     22
# 6                                                bac5  2014-08-04     40
# 7                                                bac5  2014-08-08     30
# 8                                                bac3  2014-08-29     49
# 9                                                bac5  2014-08-29     16
# 10                                               bac3  2014-10-29    132
# 11                                               bac4  2014-12-02     45
# 12                                               bac5  2014-12-07     70
# 13                                               bac2  2014-12-15     65
# 14                                               bac5  2015-02-17     78
# 15                                               bac5  2015-02-24      1
# 16                                               bac5  2015-02-24      1
# 17  Bac + 2/3 en Secrétariat / Assistanat de direc...  2015-04-01     62
# 18  Bac + 5 en Droit Fiscal / Diplôme de Juriste C...  2015-04-01      4
# 19           Diplôme d’expert comptable ou équivalent  2015-04-01      6
# 20                                               bac4  2015-04-06     67
# 21                                               bac5  2015-04-07     12
# 22                          Ingénieur en informatique  2015-05-06    112
# 23                                  Ingénieur Télécom  2015-04-28     79
# 24                          Ingénieur en informatique  2015-04-28     60
# 25           Ingénieur Téléinformatique et/ou Télécom  2015-04-28     58
# 26                          Bac + 4/5 en Informatique  2015-04-28    102
# 27                            Bac + 5 en Informatique  2015-04-28     95
# 28                          Bac + 4/5 en Informatique  2015-04-28     62
# 29          Diplôme supérieur en Comptabilité-Gestion  2015-05-06     58
# 30          Diplôme supérieur en Comptabilité-Gestion  2015-05-06     46
# 31                Fiscaliste, de formation supérieure  2015-05-06     19
# 32                Fiscaliste, de formation supérieure  2015-05-06     19
# 33        Formation supérieur en Comptabilité/Gestion  2015-05-06     95
# 34          Diplôme supérieur en Comptabilité-Gestion  2015-05-06     72
# 35                          Ingénieur en informatique  2015-05-13    126
# 36                            Bac + 5 en Informatique  2015-05-13     69
# 37                            Bac + 5 en Informatique  2015-05-13     28
# 38                            Bac + 5 en Informatique  2015-05-13     36
# 39                      Diplômé en Marketing/Commerce  2015-05-20     34
# 40                                            Bac+4/5  2015-05-31     37
# 41                  Diplôme supérieur en Comptabilité  2015-06-03     27
# 42                      Diplôme supérieur en Commerce  2015-06-03     74
# 43                  Diplôme supérieur en Comptabilité  2015-06-03     90
# 44                           Ecole d'ingénieur/Master  2015-06-10     30
# 45       Bac + 5 en Marketing, économie ou management  2015-06-11     77
# 46   Bac + 5 en marketing, économie ou banque-finance  2015-06-11     54
# 47    Bac + 4/5 en marketing, économie  ou management  2015-06-11     60
# 48     BAC + 4 et plus en Finance, Economie ou banque  2015-06-11    104
# 49      Bac + 4/5 en droit des affaires / Droit privé  2015-06-12     21
# 50                            Bac + 2 en Informatique  2015-06-12     71
# 51                  Baccalauréat ou Service Militaire  2015-06-12     28
# 52           Diplôme en mécanique et electromécanique  2015-06-17     16
# 53                              Pas de diplôme requis  2015-06-17      7
# 54                                             Bac +2  2015-06-17    138
# 55                                                            NC      0
# 56  \tBAC+2 en Informatique, option Systèmes et R...  2015-06-26     93
# 57    \tBAC + 4 et plus en Finance, Economie, banque  2015-07-03      0
# 58                                                NaN  2015-07-06     16
# 59  Licence  en information documentaire ou équiva...  2015-07-24     17
#                                                   ...         ...    ...
#
#     Views
# 0     NaN
# 1     NaN
# 2    1691
# 3    3650
# 4    2144
# 5    2017
# 6    2097
# 7    2074
# 8    4133
# 9    3034
# 10   3008
# 11   2609
# 12  11200
# 13   2823
# 14   2574
# 15   2219
# 16   2120
# 17   3034
# 18   1567
# 19   1723
# 20   3795
# 21   1121
# 22   3866
# 23   2255
# 24   1983
# 25   1866
# 26   3312
# 27   3009
# 28   2977
# 29   3119
# 30   3119
# 31   2051
# 32   2050
# 33   5606
# 34   5606
# 35   5046
# 36   3784
# 37   1434
# 38   2901
# 39   2031
# 40   1368
# 41   1508
# 42   6911
# 43   4893
# 44   1277
# 45   3452
# 46   3880
# 47   2877
# 48   3311
# 49   1651
# 50   1809
# 51   2166
# 52   1861
# 53   1727
# 54   4123
# 55      1
# 56   2175
# 57    470
# 58   1265
# 59   1102
#       ...
#
# [120 rows x 8 columns]

# %%
#Reading ratings file:
df = pd.read_csv('/home/nadine/Desktop/Memoir/data/data.csv')

# %%
df
# Out:
#     UserId  JobId  Rating
# 0        1     21       3
# 1        1      5       2
# 2        1     31       2
# 3        1     40       1
# 4        1     30       5
# 5        1     22       2
# 6        1     29       4
# 7        1     17       5
# 8        1     24       1
# 9        1      7       2
# 10       1     19       5
# 11       1     39       3
# 12       1     12       1
# 13       1     18       3
# 14       1      6       3
# 15       1     11       1
# 16       1     13       3
# 17       1      1       2
# 18       1     28       3
# 19       1     37       1
# 20       2     35       4
# 21       2     16       3
# 22       2     39       1
# 23       2      5       5
# 24       2     19       2
# 25       2     38       4
# 26       2     28       3
# 27       2     20       5
# 28       2     25       4
# 29       2     27       2
# 30       2     23       4
# 31       2     11       5
# 32       2     36       3
# 33       2     22       5
# 34       2     32       1
# 35       2     33       5
# 36       2     37       4
# 37       2      8       3
# 38       2     40       3
# 39       2      4       3
# 40       3     33       3
# 41       3     40       5
# 42       3     15       2
# 43       3      8       2
# 44       3      7       4
# 45       3     21       4
# 46       3      9       2
# 47       3     18       1
# 48       3     25       5
# 49       3     32       3
# 50       3     19       2
# 51       3     17       2
# 52       3      6       3
# 53       3     28       4
# 54       3     14       5
# 55       3     27       3
# 56       3      5       1
# 57       3     20       3
# 58       3     10       4
# 59       3      2       3
#        ...    ...     ...
#
# [400 rows x 3 columns]

# %%
# Now lets take a peak into the content of each file to understand them better.

# %%
# To get the size of rating's data
print (users_data.shape)
# To get the firts five users!
df.head()
# Out:
# (1200, 5)
#    UserId  JobId  Rating
# 0       1     21       3
# 1       1      5       2
# 2       1     31       2
# 3       1     40       1
# 4       1     30       5
#
# [5 rows x 3 columns]

# %%
# To get the size of rating's data
#print (rating.shape)
# To get the firts five users!
#rating.head()
#len(rating.UserId)

# %%
# To get the size of rating's data
#print (jobs_data.shape)
# To get the firts five users!
#jobs_data.head()

# %%
# Now we have to divide the ratings data set into test and train data for making models:
# To split the rating data into traing and test data, we can use "scikit-learn library"

# %%
from sklearn import cross_validation as cv
train_data, test_data = cv.train_test_split(df, test_size=0.25)
tn_data  = pd.DataFrame(train_data, columns=['UserId','JobId','Rating'])
ts_data  = pd.DataFrame(test_data, columns=['UserId','JobId','Rating'])
tn_data
# Out:
#     UserId  JobId  Rating
# 0       14      5       5
# 1        9     16       4
# 2       11     38       5
# 3       19     17       2
# 4        4      4       1
# 5        7     24       4
# 6        4     39       2
# 7        4     22       3
# 8       13     15       5
# 9       11     13       4
# 10       8     17       5
# 11      13     27       5
# 12       7     37       1
# 13       5     21       4
# 14      12     18       3
# 15      10     18       4
# 16      17     38       1
# 17      13     29       3
# 18      16     22       5
# 19      19     25       5
# 20       7      7       1
# 21      17     20       5
# 22      15     24       5
# 23       7      8       2
# 24      17     30       1
# 25      12     40       2
# 26       7     39       5
# 27       5     13       5
# 28      11      5       2
# 29      13     13       2
# 30       7     13       4
# 31      10      1       3
# 32       3      2       3
# 33      15      4       2
# 34       4     40       3
# 35      18      5       3
# 36       3     20       3
# 37      12     24       5
# 38       2     28       3
# 39      18     25       5
# 40      17      7       1
# 41      16     16       3
# 42      15     25       5
# 43       7     21       3
# 44      10      9       4
# 45      20     15       2
# 46      12      3       4
# 47      14     34       2
# 48       2     19       2
# 49      17     11       3
# 50       6     10       5
# 51      11      2       4
# 52      18     26       4
# 53       2     37       4
# 54      20     30       3
# 55      11     31       3
# 56      20     33       3
# 57       1     39       3
# 58       8      8       4
# 59      12     16       4
#        ...    ...     ...
#
# [300 rows x 3 columns]

# %%
# COLLABORATIVE FILTERING ALGORITHMS

# %%
## 1. Memory-Based Collaborative Filtering:

# %%
n_users = df.UserId.unique().shape[0]
n_jobs = df.JobId.unique().shape[0]
print (' Total Number of users = ' + str(n_users) + ' | Total Number of jobs = ' + str(n_jobs) )
n_users
# Out:
#  Total Number of users = 20 | Total Number of jobs = 40
# 20

# %%
# 1. User_Item Filtering Algorithm: 
## A user-item filtering will take a particular user, find users that are similar to that user based on similarity of ratings, and recommend items that those similar users liked
##  Main steps
### Build user-item matrix: X12 represents rating from user1 to job2
### Calculate the simmility: user simalality based on ratings simality and job similarity based  on ratings simalarity using cosine similarity
### Create the simility matrix

# %%
tn_data
# Out:
#     UserId  JobId  Rating
# 0     1797     86       4
# 1     1363    121       3
# 2     1153    128       4
# 3     2485     75       3
# 4      445     56       5
# 5     1197     74       4
# 6     1177     78       3
# 7     2024     44       2
# 8     1105    117       3
# 9     2240     99       3
# 10     917     87       5
# 11    1173    147       4
# 12    1333    144       2
# 13     128    125       2
# 14     651    109       1
# 15    1675     53       4
# 16     803     23       1
# 17     217     58       1
# 18     323     68       3
# 19    2070     94       3
# 20    2021     88       1
# 21    2287    141       4
# 22     496     87       1
# 23     740     72       2
# 24    2101     76       4
# 25    1841    123       5
# 26    1606     71       4
# 27     604     24       3
# 28    1399    110       1
# 29     313    149       4
# 30     770    106       1
# 31    1472    102       2
# 32    1276     32       4
# 33    2093      4       4
# 34     154     25       2
# 35    1343     81       4
# 36    2108    122       3
# 37    2055    133       4
# 38    2491     27       2
# 39     987     35       3
# 40     967     71       4
# 41    1892      2       3
# 42     737     96       3
# 43     228     20       3
# 44      95    117       4
# 45    1590     70       3
# 46    2407     79       2
# 47     783     80       1
# 48     914     68       4
# 49     454    130       5
# 50     863     68       3
# 51     972    104       5
# 52    1145     61       1
# 53    1026    113       5
# 54    1636     83       3
# 55    2480     78       5
# 56    1556     81       2
# 57     581      7       3
# 58    2075     98       4
# 59    1419     78       3
#        ...    ...     ...
#
# [149973 rows x 3 columns]

# %%
tn_data['JobId']
# Out:
# 0      86
# 1     121
# 2     128
# 3      75
# 4      56
# 5      74
# 6      78
# 7      44
# 8     117
# 9      99
# 10     87
# 11    147
# 12    144
# 13    125
# 14    109
# ...
# 149958     10
# 149959     80
# 149960     38
# 149961     23
# 149962     72
# 149963     93
# 149964    118
# 149965     67
# 149966     79
# 149967     24
# 149968     78
# 149969     24
# 149970     37
# 149971     64
# 149972     47
# Name: JobId, Length: 149973, dtype: int64

# %%
### Build user-item matrix for Traing dataset
train_data_matrix = np.zeros((n_users, n_jobs))
for line in tn_data.itertuples():
    train_data_matrix[line[1]-1, line[2]-1] = line[3]
    
### Build user-item matrix for Testing dataset
test_data_matrix = np.zeros((n_users, n_jobs))
for line in ts_data.itertuples():
    test_data_matrix[line[1]-1, line[2]-1] = line[3]

# %%
#train_data_matrix,test_data_matrix,
train_data_matrix[:1,:2]
# Out:
# array([[ 4.,  4.]])

# %%
### Compute the cosine similarity
## A distance metric commonly used in Recommender system is 
## cosine simmilarity and uses rating as a n-dimensional matrix
## and the similarity is calculated based on the angle between these vectors.

# %%
from sklearn.metrics.pairwise import pairwise_distances
user_similarity = pairwise_distances(train_data_matrix, metric='cosine')
item_similarity = pairwise_distances(train_data_matrix.T, metric='cosine')

# %%
print(item_similarity[:4, :4])
print(user_similarity[:4, :4])
# Out:
# [[ 0.          0.72034685  0.70908258  0.68069213]
#  [ 0.72034685  0.          0.65420227  0.67605764]
#  [ 0.70908258  0.65420227  0.          0.66669974]
#  [ 0.68069213  0.67605764  0.66669974  0.        ]]
# [[ 0.          0.69560507  0.79309201  0.74571635]
#  [ 0.69560507  0.          0.66723356  0.74745633]
#  [ 0.79309201  0.66723356  0.          0.71638546]
#  [ 0.74571635  0.74745633  0.71638546  0.        ]]

# %%
data_sims = pd.DataFrame(user_similarity)
data_sims.ix[:1, :1]
# Out:
#           0         1
# 0  0.000000  0.695605
# 1  0.695605  0.000000
#
# [2 rows x 2 columns]

# %%
# Let us check the computational time
# %timeit pairwise_distances(train_data_matrix, metric='cosine')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e28fe0a7c332> in <module>()
#       1 # Let us check the computational time
# ----> 2 get_ipython().magic(u"timeit pairwise_distances(train_data_matrix, metric='cosine')")
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-58> in timeit(self, line, cell)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#    1042             number = 1
#    1043             for _ in range(1, 10):
# -> 1044                 time_number = timer.timeit(number)
#    1045                 worst_tuning = max(worst_tuning, time_number / number)
#    1046                 if time_number >= 0.2:
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magics/execution.pyc in timeit(self, number)
#     137         gc.disable()
#     138         try:
# --> 139             timing = self.inner(it, self.timer)
#     140         finally:
#     141             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# NameError: global name 'pairwise_distances' is not defined

# %%
def predict(ratings, similarity, type='user'):
    if type == 'user':
        mean_user_rating = ratings.mean(axis=1)
        #You use np.newaxis so that mean_user_rating has same format as ratings
        ratings_diff = (ratings - mean_user_rating[:, np.newaxis]) 
        pred = mean_user_rating[:, np.newaxis] + similarity.dot(ratings_diff) / np.array([np.abs(similarity).sum(axis=1)]).T
    elif type == 'job':
        pred = ratings.dot(similarity) / np.array([np.abs(similarity).sum(axis=1)])     
    return pred

# %%
# with the calculated simalarity matrix now we can use it to predict tyhe non rated jobs offers!

# %%
item_prediction = predict(train_data_matrix, item_similarity, type='job')
user_prediction = predict(train_data_matrix, user_similarity, type='user')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0d0ac6e54000> in <module>()
# ----> 1 item_prediction = predict(train_data_matrix, item_similarity, type='job')
#       2 user_prediction = predict(train_data_matrix, user_similarity, type='user')
#
# NameError: name 'train_data_matrix' is not defined

# %%
# %timeit predict(train_data_matrix, item_similarity, type='job')
# %timeit predict(train_data_matrix, user_similarity, type='user')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a8f4e3bfb860> in <module>()
# ----> 1 get_ipython().magic(u"timeit predict(train_data_matrix, item_similarity, type='job')")
#       2 get_ipython().magic(u"timeit predict(train_data_matrix, user_similarity, type='user')")
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-58> in timeit(self, line, cell)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#    1042             number = 1
#    1043             for _ in range(1, 10):
# -> 1044                 time_number = timer.timeit(number)
#    1045                 worst_tuning = max(worst_tuning, time_number / number)
#    1046                 if time_number >= 0.2:
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magics/execution.pyc in timeit(self, number)
#     137         gc.disable()
#     138         try:
# --> 139             timing = self.inner(it, self.timer)
#     140         finally:
#     141             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# NameError: global name 'train_data_matrix' is not defined

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
def rmse(prediction, ground_truth):
    prediction = prediction[ground_truth.nonzero()].flatten() 
    ground_truth = ground_truth[ground_truth.nonzero()].flatten()
    return sqrt(mean_squared_error(prediction, ground_truth))

# %%
print 'User-based CF RMSE: ' + str(rmse(user_prediction, test_data_matrix))
print 'Item-based CF RMSE: ' + str(rmse(item_prediction, test_data_matrix))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3ee8ac9a326d> in <module>()
# ----> 1 print 'User-based CF RMSE: ' + str(rmse(user_prediction, test_data_matrix))
#       2 print 'Item-based CF RMSE: ' + str(rmse(item_prediction, test_data_matrix))
#
# NameError: name 'rmse' is not defined

# %%
sparsity=round(1.0-len(df)/float(n_users*n_jobs),3)
print 'The sparsity level of WutikoData is ' +  str(sparsity*100) + '%'
# Out:
# The sparsity level of WutikoData is 46.7%

# %%
import scipy.sparse as sp
from scipy.sparse.linalg import svds

#get SVD components from train matrix. Choose k.
u, s, vt = svds(train_data_matrix, k = 20)
s_diag_matrix=np.diag(s)
X_pred = np.dot(np.dot(u, s_diag_matrix), vt)
print 'User-based CF MSE: ' + str(rmse(X_pred, test_data_matrix))
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/core/fromnumeric.py:2699: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# User-based CF MSE: 2.69257953796

# %%
## Content-Boosted Collaborative Filtering:
# This approach uses a content-based predictor to enhance existing user data,
# and then provides personalized suggestions through collaborative filtering
# Content-Boosted Collaborative Filtering, performs better than a pure content-based predictor, pure
# collaborative filter, and a naive hybrid approach.

# %%
# Model Evaluation
# The metrics for evaluating the accuracy of a prediction algorithm can be divided into two main categories: 
# statistical accuracy metrics and decision-support metrics.
# 1. Statistical accuracy metrics evaluate the accu-
# racy of a predictor by comparing predicted values with user-
#provided values. To measure statistical accuracy we use the
# mean absolute error (MAE) metric — defined as the average
# absolute difference between predicted ratings and actual rat-
# ings. In our experiments we computed the MAE on the test
# set for each user, and then averaged over the set of test users

# %%
# 2.Decision-support accuracy measures how well predic-
# tions help users select high-quality items. We use Re-
# ceiver Operating Characteristic (ROC) sensitivity to mea-
# sure decision-support accuracy. A predictor can be treated as a filter, where predicting a high rating for an item is
# equivalent to accepting the item, and predicting a low rating
# is equivalent to rejecting the item. The ROC sensitivity is
# given by the area under the ROC curve — a curve that plots
# sensitivity versus 1-specificity for a predictor. Sensitivity is
# defined as the probability that a good item is accepted by the
# filter; and specificity is defined as the probability that a bad
# item is rejected by the filter. We consider an item good if the
# user gave it a rating of 4 or above, otherwise we consider the
# item bad.
