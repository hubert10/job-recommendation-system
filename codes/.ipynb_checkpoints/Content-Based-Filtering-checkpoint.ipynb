# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

df = pd.read_csv("/home/nadine/Desktop/Memoir/data/content.csv")
df
# Out:
#       id                                               name  \
# 0      1              Un(e) directeur(trice) des formations
# 1      2          Un(e) responsable marketing et commercial
# 2      3                    Un(e) assistant(e) de direction
# 3      4                               Vacancy Announcement
# 4      5                                         Commercial
# 5      6                   Commercial / business developper
# 6      7                  Hellofood.sn recrute un comptable
# 7      8     Africa Internet Group recruit a Cash COLLECTOR
# 8      9                             Un assistant comptable
# 9     10           DÃ©veloppeurs back-end & front-end (H/F)
# 10    11  La LONASE recrute un(e) Directeur(rice) des Sy...
# 11    12                  ChargÃ©(e) de communication (H/F)
# 12    13  Assistante administrative, financiÃ¨re et orga...
# 13    14                      HR Business Partner - Senegal
# 14    15                                      CFO - Senegal
# 15    16  Un(e) Assistant(e) de Direction Bilingue (Fran...
# 16    17  Un (01) Senior Manager Tax (Bilingue FranÃ§ais...
# 17    18  Un Manager Responsable de DÃ©partement Experti...
# 18    19                      Consultant contrÃ´le qualitÃ©
# 19    20  Responsable du DÃ©partement Expertise Comptabl...
# 20    21                                  Chef de Projet SI
# 21    22                            IngÃ©nieur RÃ©seau Data
# 22    23                                  IngÃ©nieur Etudes
# 23    24                                   IngÃ©nieur Radio
# 24    25       Administrateur SystÃ¨me et Base de donnÃ©es
# 25    26             IngÃ©nieur de Production  Informatique
# 26    27                           Administrateur Stockage
# 27    28                                           Auditeur
# 28    29                                           Auditeur
# 29    30                                         Fiscaliste
# ..   ...                                                ...
# 88    89                               IngÃ©nieur QualitÃ©
# 89    90                        IngÃ©nieur de Test Logiciel
# 90    91                       Chef DÃ©partement Support RH
# 91    92                             SAP FI ROLL OUT AFRICA
# 92    93                         Directeur commercial (H/F)
# 93    94       Community Manager bilingue franÃ§ais/anglais
# 94    95        Digital Designer bilingue franÃ§ais/anglais
# 95    96  INGENIEUR ETUDES ET DEVELOPPEMENT iOS â€“ Obje...
# 96    97  DÃ©veloppeur Web expÃ©rimentÃ© Front End et We...
# 97    98           Consultant technique et fonctionnel paie
# 98    99                        Responsable Parc Automobile
# 99   100              Infographiste / Designer Web & Mobile
# 100  101                           Assistant chef de projet
# 101  102          Assistant Responsable Ressources humaines
# 102  103           Architecte SystÃ¨me dâ€™Information (SI)
# 103  104                       ChargÃ© de lâ€™Exploitation
# 104  105                            Coordonnateur Technique
# 105  106                            Responsable Datacenter
# 106  107                               Responsable Energie
# 107  108                            Responsable Logistique
# 108  109                      Stagiaire Consultant QualitÃ©
# 109  110                      Consultant contrÃ´le qualitÃ©
# 110  111                      Un Directeur de Magasin (H/F)
# 111  112   ChargÃ© de suivi des travaux de la fibre optique
# 112  113                         DÃ©veloppeur Java Checkout
# 113  114  Tech Leader Architecture et DÃ©veloppement Jav...
# 114  115  Tech Leader Architecture Java-J2EE/RÃ©fÃ©rant ...
# 115  116                                Directeur Technique
# 116  117                                  Commerciaux (H/F)
# 117  118    un Responsable Administratif & Financier (H/F).
#
#                                                   slug   experience  \
# 0                        un-e-directeur-des-formations     > 5 ans
# 1             un-e-responsable-marketing-et-commercial  Experienced
# 2                          une-assistante-de-direction  Experienced
# 3                                 vacancy-announcement          NaN
# 4                        stagiaire-descriptif-de-poste          NaN
# 5                       commercial-business-developper          NaN
# 6                    hellofood-sn-recrute-un-comptable          NaN
# 7       africa-internet-group-recruit-a-cash-collector          NaN
# 8                                  assistant-comptable          NaN
# 9                  developpeurs-back-end-front-end-h-f          NaN
# 10   la-lonase-recrute-un-e-directeur-rice-des-syst...          NaN
# 11                       charge-e-de-communication-h-f          NaN
# 12   assistante-administrative-financiere-et-organi...          NaN
# 13                         hr-business-partner-senegal          NaN
# 14                  director-of-accounting-and-finance          NaN
# 15   un-e-assistant-e-de-direction-bilingue-francai...          NaN
# 16   un-01-senior-manager-tax-bilingue-francais-ang...          NaN
# 17   un-manager-responsable-de-departement-expertis...          NaN
# 18                         consultant-controle-qualite          NaN
# 19   responsable-du-departement-expertise-comptable...          NaN
# 20                                   chef-de-projet-si          NaN
# 21                               ingenieur-reseau-data          NaN
# 22                                    ingenieur-etudes          NaN
# 23                                     ingenieur-radio          NaN
# 24           administrateur-systeme-et-base-de-donnees          NaN
# 25                ingenieur-de-production-informatique          NaN
# 26                             administrateur-stockage          NaN
# 27                                            auditeur          NaN
# 28                                            auditeur          NaN
# 29                                          fiscaliste          NaN
# ..                                                 ...          ...
# 88                                   ingenieur-qualite          NaN
# 89                          ingenieur-de-test-logiciel          NaN
# 90                         chef-departement-support-rh          NaN
# 91                              sap-fi-roll-out-africa          NaN
# 92                            directeur-commercial-h-f          NaN
# 93         community-manager-bilingue-francais-anglais          NaN
# 94          digital-designer-bilingue-francais-anglais          NaN
# 95   ingenieur-etudes-et-developpement-ios-objective-c          NaN
# 96   developpeur-web-experimente-front-end-et-webde...          NaN
# 97            consultant-technique-et-fonctionnel-paie          NaN
# 98                         responsable-parc-automobile          NaN
# 99                   infographiste-designer-web-mobile          NaN
# 100                           assistant-chef-de-projet          NaN
# 101          assistant-responsable-ressources-humaines          NaN
# 102                architecte-systeme-d-information-si          NaN
# 103                           charge-de-l-exploitation          NaN
# 104                            coordonnateur-technique          NaN
# 105                             responsable-datacenter          NaN
# 106                                responsable-energie          NaN
# 107                             responsable-logistique          NaN
# 108                       stagiaire-consultant-qualite          NaN
# 109                        consultant-controle-qualite          NaN
# 110                        un-directeur-de-magasin-h-f          NaN
# 111    charge-de-suivi-des-travaux-de-la-fibre-optique          NaN
# 112                          developpeur-java-checkout          NaN
# 113  tech-leader-architecture-et-developpement-java...          NaN
# 114  tech-leader-architecture-java-j2ee-referant-pr...          NaN
# 115                                directeur-technique          NaN
# 116                                    commerciaux-h-f          NaN
# 117         un-responsable-administratif-financier-h-f          NaN
#
#                                            description
# 0    <ul><li>&euml;tre &acirc;g&eacute; entre 30 et...
# 1    <p>Le/La responsable marketing et commercial d...
# 2    <p><strong>Le profil recherch&eacute; doit:&nb...
# 3    <p>-Dipl&ocirc;me universitaire informatique o...
# 4    <p>Bac+5 au minimum.</p><p>Vous &ecirc;tes tit...
# 5    <p><strong>PROFIL</strong></p><p>Vous avez acq...
# 6    <ul><li>Titulaire d&#39;un <strong>Bac+2/3 en ...
# 7    <ul>\n<li style=\"text-align: justify;\">Minim...
# 8    <p><strong>Le profil recherch&eacute; doit:</s...
# 9    <p><strong>Pr&eacute;-requis technique</strong...
# 10   <p><strong>Qualit&eacute;s attendues :</strong...
# 11   <p>PROFIL RECHERCH&Eacute; :<br />Etudiant(e) ...
# 12   <ul><li>Sens de l&#39;acceuil</li><li>Notions ...
# 13   <p>The next HR Business Partner will fulfil th...
# 14   <p>A successful candidate will fulfill the fol...
# 15   <ul><li><p>Bac + 2/3 en secr&eacute;tariat / a...
# 16   <ul><li><p>Bac + 5 en Droit Fiscal / Dipl&ocir...
# 17   <ul><li><p>Dipl&ocirc;me d&rsquo;expert compta...
# 18   <p>Nous recherchons des candidats aimant le tr...
# 19   <p>De formation sup&eacute;rieure comptable, l...
# 20   <p>Les exigences&nbsp;pour ce poste sont les s...
# 21   <p>Pour ce poste, les comp&eacute;tences suiva...
# 22   <p>Pour ce poste, les comp&eacute;tences suiva...
# 23   <p>Les comp&eacute;tences suivantes sont requi...
# 24   <p>Les comp&eacute;tences suivantes sont requi...
# 25   <p>Les comp&eacute;tences suivantes sont requi...
# 26   <p>Pour ce poste, les comp&eacute;tences suiva...
# 27   <ul><li>Dipl&ocirc;m&eacute;(e) Master d&#39;u...
# 28   <ul><li>Dipl&ocirc;m&eacute;(e) Master d&#39;u...
# 29   <ul><li>Fiscaliste, de formation sup&eacute;ri...
# ..                                                 ...
# 88   <p>- Un minimum d&#39;exp&eacute;rience de 3 a...
# 89   <p>- Bac+5</p><p>- Anglais Courant</p><p>-Exp&...
# 90   <p><strong>PROFIL</strong></p><ul><li>Bac+ 5 e...
# 91   <ul><li><p>Consultants Senior SAP FI</p></li><...
# 92   <ul><li>Une bonne connaissance du secteur de l...
# 93   <ul><li>Bilingue fran&ccedil;ais &amp; anglais...
# 94   <ol><li><strong>Ma&icirc;trise </strong><ul><l...
# 95                                                 NaN
# 96                                                 NaN
# 97   <p><strong>Profil</strong></p><p><!--[if !supp...
# 98   <ul><li>BTS en logistique et transport, m&eacu...
# 99                                                 NaN
# 100  <p><strong>Profil recherch&eacute;</strong></p...
# 101  <p>Avoir un dipl&ocirc;me de bac +4 avec 4 ans...
# 102  <p><strong>Profil recherch&eacute;</strong></p...
# 103  <p><strong>Profil recherch&eacute;</strong></p...
# 104  <p><strong>Profil recherch&eacute;</strong></p...
# 105  <p><strong>Profil recherch&eacute;</strong></p...
# 106  <p><strong>Profil recherch&eacute;</strong></p...
# 107  <p><strong>Profil recherch&eacute;</strong></p...
# 108                                                NaN
# 109  <p><!--[if gte mso 9]><xml>\n <o:OfficeDocumen...
# 110  <p><strong>Conditions de candidature </strong>...
# 111  <p><strong>Missions</strong></p><p><strong>&nb...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115  <p>De formation ing&eacute;nieur BTP ou &eacut...
# 116  <p>Le candidat devra justifier d&rsquo;un dipl...
# 117  <p>Les qualit&eacute;s attendues des candidats...
#
# [118 rows x 5 columns]

# %%
for col in df.columns:
    if 'Unnamed' in col:
        del df[col]

# %%
ds = df.drop('experience', axis=1)
#ds =  d.dropna()

# %%
ds.head(40)
# Out:
#     id                                               name  \
# 0    1              Un(e) directeur(trice) des formations
# 1    2          Un(e) responsable marketing et commercial
# 2    3                    Un(e) assistant(e) de direction
# 3    4                               Vacancy Announcement
# 4    5                                         Commercial
# 5    6                   Commercial / business developper
# 6    7                  Hellofood.sn recrute un comptable
# 7    8     Africa Internet Group recruit a Cash COLLECTOR
# 8    9                             Un assistant comptable
# 9   10           DÃ©veloppeurs back-end & front-end (H/F)
# 10  11  La LONASE recrute un(e) Directeur(rice) des Sy...
# 11  12                  ChargÃ©(e) de communication (H/F)
# 12  13  Assistante administrative, financiÃ¨re et orga...
# 13  14                      HR Business Partner - Senegal
# 14  15                                      CFO - Senegal
# 15  16  Un(e) Assistant(e) de Direction Bilingue (Fran...
# 16  17  Un (01) Senior Manager Tax (Bilingue FranÃ§ais...
# 17  18  Un Manager Responsable de DÃ©partement Experti...
# 18  19                      Consultant contrÃ´le qualitÃ©
# 19  20  Responsable du DÃ©partement Expertise Comptabl...
# 20  21                                  Chef de Projet SI
# 21  22                            IngÃ©nieur RÃ©seau Data
# 22  23                                  IngÃ©nieur Etudes
# 23  24                                   IngÃ©nieur Radio
# 24  25       Administrateur SystÃ¨me et Base de donnÃ©es
# 25  26             IngÃ©nieur de Production  Informatique
# 26  27                           Administrateur Stockage
# 27  28                                           Auditeur
# 28  29                                           Auditeur
# 29  30                                         Fiscaliste
# 30  31                                         Fiscaliste
# 31  32                                          Comptable
# 32  33                                          Comptable
# 33  34          30 IngÃ©nieurs de dÃ©veloppement logiciel
# 34  35               10 Consultants MICROSOFT Application
# 35  36                  5 Consultants ORACLE Applications
# 36  37                     5 Consultants SAP Applications
# 37  38                              Deux (2) Chefs de pub
# 38  39             INGENIEUR ETUDES ET DEVELOPPEMENT WEB
# 39  40  emploi</strong> : Bac+4/ 5 (avec au moins une ...
#
#                                                  slug  \
# 0                       un-e-directeur-des-formations
# 1            un-e-responsable-marketing-et-commercial
# 2                         une-assistante-de-direction
# 3                                vacancy-announcement
# 4                       stagiaire-descriptif-de-poste
# 5                      commercial-business-developper
# 6                   hellofood-sn-recrute-un-comptable
# 7      africa-internet-group-recruit-a-cash-collector
# 8                                 assistant-comptable
# 9                 developpeurs-back-end-front-end-h-f
# 10  la-lonase-recrute-un-e-directeur-rice-des-syst...
# 11                      charge-e-de-communication-h-f
# 12  assistante-administrative-financiere-et-organi...
# 13                        hr-business-partner-senegal
# 14                 director-of-accounting-and-finance
# 15  un-e-assistant-e-de-direction-bilingue-francai...
# 16  un-01-senior-manager-tax-bilingue-francais-ang...
# 17  un-manager-responsable-de-departement-expertis...
# 18                        consultant-controle-qualite
# 19  responsable-du-departement-expertise-comptable...
# 20                                  chef-de-projet-si
# 21                              ingenieur-reseau-data
# 22                                   ingenieur-etudes
# 23                                    ingenieur-radio
# 24          administrateur-systeme-et-base-de-donnees
# 25               ingenieur-de-production-informatique
# 26                            administrateur-stockage
# 27                                           auditeur
# 28                                           auditeur
# 29                                         fiscaliste
# 30                                         fiscaliste
# 31                                          comptable
# 32                                          comptable
# 33            30-ingenieurs-de-developpement-logiciel
# 34               10-consultants-microsoft-application
# 35                  5-consultants-oracle-applications
# 36                     5-consultants-sap-applications
# 37                                        chef-de-pub
# 38              ingenieur-etudes-et-developpement-web
# 39                                      re exp&eacute
#
#                                           description
# 0   <ul><li>&euml;tre &acirc;g&eacute; entre 30 et...
# 1   <p>Le/La responsable marketing et commercial d...
# 2   <p><strong>Le profil recherch&eacute; doit:&nb...
# 3   <p>-Dipl&ocirc;me universitaire informatique o...
# 4   <p>Bac+5 au minimum.</p><p>Vous &ecirc;tes tit...
# 5   <p><strong>PROFIL</strong></p><p>Vous avez acq...
# 6   <ul><li>Titulaire d&#39;un <strong>Bac+2/3 en ...
# 7   <ul>\n<li style=\"text-align: justify;\">Minim...
# 8   <p><strong>Le profil recherch&eacute; doit:</s...
# 9   <p><strong>Pr&eacute;-requis technique</strong...
# 10  <p><strong>Qualit&eacute;s attendues :</strong...
# 11  <p>PROFIL RECHERCH&Eacute; :<br />Etudiant(e) ...
# 12  <ul><li>Sens de l&#39;acceuil</li><li>Notions ...
# 13  <p>The next HR Business Partner will fulfil th...
# 14  <p>A successful candidate will fulfill the fol...
# 15  <ul><li><p>Bac + 2/3 en secr&eacute;tariat / a...
# 16  <ul><li><p>Bac + 5 en Droit Fiscal / Dipl&ocir...
# 17  <ul><li><p>Dipl&ocirc;me d&rsquo;expert compta...
# 18  <p>Nous recherchons des candidats aimant le tr...
# 19  <p>De formation sup&eacute;rieure comptable, l...
# 20  <p>Les exigences&nbsp;pour ce poste sont les s...
# 21  <p>Pour ce poste, les comp&eacute;tences suiva...
# 22  <p>Pour ce poste, les comp&eacute;tences suiva...
# 23  <p>Les comp&eacute;tences suivantes sont requi...
# 24  <p>Les comp&eacute;tences suivantes sont requi...
# 25  <p>Les comp&eacute;tences suivantes sont requi...
# 26  <p>Pour ce poste, les comp&eacute;tences suiva...
# 27  <ul><li>Dipl&ocirc;m&eacute;(e) Master d&#39;u...
# 28  <ul><li>Dipl&ocirc;m&eacute;(e) Master d&#39;u...
# 29  <ul><li>Fiscaliste, de formation sup&eacute;ri...
# 30  <ul><li>Fiscaliste, de formation sup&eacute;ri...
# 31  <ul><li>Issu d&rsquo;une formation de type Bac...
# 32  <p>Issu d&rsquo;une formation de type Bac +2/3...
# 33  <ul><li>Formation en Ingenierie informatique (...
# 34  <ul><li><p>Bac + 5 en Informatique</p></li><li...
# 35  <p>Comp&eacute;tences et Aptitudes sp&eacute;c...
# 36  <ul><li>Bac + 5 en Informatique</li><li><p>Nom...
# 37  <ul><li>De formation sup&eacute;rieure Marketi...
# 38                                                NaN
# 39                                veloppement d&rsquo

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(ds['slug'])

cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

results = {}

for idx, row in ds.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-100:-1]
    similar_items = [(cosine_similarities[idx][i], ds['id'][i]) for i in similar_indices]

    # First item is the item itself, so remove it.
    # Each dictionary entry is like: [(1,2), (3,4)], with each tuple being (score, item_id)
    results[row['id']] = similar_items[1:]
    
print('done!')
# Out:
# done!

# %%
# hacky little function to get a friendly item name from the description field, given an item ID
def item(id):
    return ds.loc[ds['id'] == id]['name'].tolist()[0].split(' - ')[0]

# Just reads the results out of the dictionary. No real logic here.
def recommend(item_id, num):
    print("Recommending " + str(num) + " jobs similar to " + item(item_id) + "...")
    print("-------")
    recs = results[item_id][:num]
    for rec in recs:
        print("Recommended: " + item(rec[1]) + " (score:" + str(rec[0]) + ")")

# Just plug in any item id here (1-500), and the number of recommendations you want (1-99)
# You can get a list of valid item IDs by evaluating the variable 'ds', or a few are listed below

recommend(item_id=11, num=5)
# Out:
# Recommending 5 jobs similar to La LONASE recrute un(e) Directeur(rice) des SystÃ¨mes dâ€™Information (DSI)...
# -------
# Recommended: Un(e) directeur(trice) des formations (score:0.096268844252)
# Recommended: Un(e) Directeur (trice) des comptabilitÃ©s (score:0.0798078367801)
# Recommended: Directeur commercial (H/F) (score:0.0782754636855)
# Recommended: Directeur Technique (score:0.0738496789408)
# Recommended: Un Directeur de Magasin (H/F) (score:0.0700432897456)
